# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=localhost;"
    "DATABASE=smartstock_db;"
    "Trusted_Connection=yes;"
)

cursor = conn.cursor()

# %%
from faker import Faker
import random
from datetime import datetime, timedelta

fake = Faker("pt_BR")

# %%
for _ in range(5):

    nome = fake.name()

    cursor.execute("""
        INSERT INTO dono_loja (nome) VALUES (?)
    """, nome)
